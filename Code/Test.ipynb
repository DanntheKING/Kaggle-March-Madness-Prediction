# %% [markdown]
# # **March Madness Prediction Project**
#
#
# #### Date: 2-15-2025 ####
# #### By: CoNiya Butler & Daniel Davis ####

# %% [markdown]
# ## **Step 1: Import Python Package** ##

# %%
# Pandas is a software library written for the Python programming language for data manipulation and analysis.
import pandas as pd
# NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays
import numpy as np
# Matplotlib is a plotting library for python and pyplot gives us a MatLab like plotting framework. We will use this in our plotter function to plot data.
import matplotlib.pyplot as plt
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics
import seaborn as sns
# Preprocessing allows us to standarsize our data
from sklearn import preprocessing
# Allows us to split our data into training and testing data
from sklearn.model_selection import train_test_split
# Allows us to test parameters of classification algorithms and find the best one
from sklearn.model_selection import GridSearchCV
# Logistic Regression classification algorithm
from sklearn.linear_model import LogisticRegression
# Support Vector Machine classification algorithm
from sklearn.svm import SVC
# Decision Tree classification algorithm
from sklearn.tree import DecisionTreeClassifier
# K Nearest Neighbors classification algorithm
from sklearn.neighbors import KNeighborsClassifier
# Brier score and mean loss function
from sklearn.metrics import brier_score_loss, mean_squared_error
# PyTorch library
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# ## **Step 2: Explore the data** ##

# %%
seed_df = pd.read_csv("/app/March-Madness-Prediction/Data/march-machine-learning-mania-2025/MNCAATourneySeeds.csv")
conferences = pd.read_csv("/app/March-Madness-Prediction/Data/march-machine-learning-mania-2025/Conferences.csv")
MConferencesTourneyGames = pd.read_csv("/app/March-Madness-Prediction/Data/march-machine-learning-mania-2025/MConferenceTourneyGames.csv")
submission_df = pd.read_csv("/app/March-Madness-Prediction/Data/march-machine-learning-mania-2025/SampleSubmissionStage1.csv")
MNCAATourneyDetailedResults = pd.read_csv("/app/March-Madness-Prediction/Data/march-machine-learning-mania-2025/MNCAATourneyDetailedResults.csv")
MTeams = pd.read_csv("/app/March-Madness-Prediction/Data/march-machine-learning-mania-2025/MTeams.csv")
MNCAACompantResults = pd.read_csv("/app/March-Madness-Prediction/Data/march-machine-learning-mania-2025/MNCAATourneyCompactResults.csv")
MRegularSeasonCompactResult = pd.read_csv("/app/March-Madness-Prediction/Data/march-machine-learning-mania-2025/MRegularSeasonCompactResults.csv")
MRegularSeasonDetailResult = pd.read_csv("/app/March-Madness-Prediction/Data/march-machine-learning-mania-2025/MRegularSeasonDetailedResults.csv")

# %%
submission_df
pd.set_option('display.max_columns', None)

# %%
WteamRegular_df = MRegularSeasonDetailResult[(MRegularSeasonDetailResult["Season"] == 2021) & (MRegularSeasonDetailResult["WTeamID"] == 1101)]
WteamRegular_df["W/L"] = 1
LteamRegular_df =MRegularSeasonDetailResult[(MRegularSeasonDetailResult["Season"] == 2021) & (MRegularSeasonDetailResult["LTeamID"] == 1101)]
LteamRegular_df["W/L"] = 0
LteamRegular_df
# Out:
# /tmp/ipykernel_523/292184409.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WteamRegular_df["W/L"] = 1
# /tmp/ipykernel_523/292184409.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LteamRegular_df["W/L"] = 0
#        Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 93349    2021      37     1403      51     1101      44    H      0    12
# 93728    2021      50     1116      85     1101      72    H      0    26
# ...

# %%
TeamRegular_df = pd.concat([WteamRegular_df,LteamRegular_df])
TeamRegular_df
# Out:
#        Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 92832    2021      23     1101      70     1190      47    N      0    20
# 92936    2021      25     1101      80     1122      72    N      0    29
# 92987    2021      26     1101      70     1303      58    N      0    26
# 93200    2021      33     1101      69     1470      48    H      0    23
# 93947    2021      61     1101      83     1249      65    H      0    30
# 94111    2021      65     1101      66     1223      63    A      0    27
# 94466    2021      75     1101      76     1368      42    H      0    24
# 94746    2021      82     1101      93     1146      58    H      0    34
# 94921    2021      86     1101      82     1372      62    H      0    26
# 95015    2021      89     1101      75     1230      67    A      0    25
# 95289    2021      96     1101      77     1249      62    A      0    30
# 95404    2021      98     1101      82     1394      69    A      0    31
# ...

# %%
# Convert to numeric indices
WLoc_to_index = {"N": 0, "A": 1, "H":2}
# Now the team column becomes:
Wloc_column_encoded = [WLoc_to_index[team] for team in TeamRegular_df["WLoc"]]
type(Wloc_column_encoded)  # Output: [0, 1, 2]
TeamRegular_df.insert(6, "WlocEcoded", Wloc_column_encoded)
TeamRegular_df
TeamRegular_df = TeamRegular_df.drop(["WLoc"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WLoc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 4
#       2 WLoc_to_index = {"N": 0, "A": 1, "H":2}
# ...

# %%
TeamRegular_df = New_df
TeamRegular_df
# Out:
#        Season  DayNum  WTeamID  WScore  LTeamID  LScore  WlocEcoded  NumOT  \
# 92832    2021      23     1101      70     1190      47           0      0
# 92936    2021      25     1101      80     1122      72           0      0
# 92987    2021      26     1101      70     1303      58           0      0
# 93200    2021      33     1101      69     1470      48           2      0
# 93947    2021      61     1101      83     1249      65           2      0
# 94111    2021      65     1101      66     1223      63           1      0
# 94466    2021      75     1101      76     1368      42           2      0
# 94746    2021      82     1101      93     1146      58           2      0
# 94921    2021      86     1101      82     1372      62           2      0
# 95015    2021      89     1101      75     1230      67           1      0
# 95289    2021      96     1101      77     1249      62           1      0
# ...

# %%
#Class that will convert the dataframe to a tensor
class PandasDataset(Dataset):
    def __init__(self, df, target_col):
        self.features = df.drop(target_col, axis=1).values.astype("float64")
        self.target = df[target_col].values.astype("float64")

    def __len__(self):
        return len(self.target)

    def __getitem__(self, index):
        return torch.tensor(self.features[index], dtype=torch.float), torch.tensor(self.target[index], dtype=torch.float)

# Assuming your DataFrame is called 'df' and the target column is 'target'
df = TeamRegular_df
target_col = 'W/L'

dataset = PandasDataset(df, target_col)
dataloader = DataLoader(dataset, batch_size=32)

# %%
x_train = dataset[0][0]
y_train = dataset[1][0]

# %%
# Model parameters
num_numerical = 3  # Win %, PPG, Def Rating
num_Locs = 3  # Unique teams (N, A, H)
embedding_dim = 2  # Small embedding for location

# %%
# Define the Neural Network with Embeddings
class BasketballNN(nn.Module):
    def __init__(self):
        super(BasketballNN, self).__init__()
        
        # Embedding layer for the categorical feature (Wloc)
        self.team_embedding = nn.Embedding(num_embeddings=num_Locs, embedding_dim=embedding_dim)
        
        # Fully connected layers
        self.fc1 = nn.Linear(num_numerical + embedding_dim, 16)  # Numerical + Team Embedding
        self.fc2 = nn.Linear(16, 8)
        self.fc3 = nn.Linear(8, 1)
        self.sigmoid = nn.Sigmoid()  # Probability output

    def forward(self, x_numerical, x_team):
        # Get the embedding vector for the team
        team_embedded = self.team_embedding(x_team.long())  # Convert team index to embeddings
        x = torch.cat([x_numerical, team_embedded], dim=1)  # Concatenate numerical features with embedding
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        x = self.sigmoid(x)  # Output probability (between 0 and 1)
        return x

# Initialize the model
model = BasketballNN()
criterion = nn.BCELoss()  # Binary Cross-Entropy Loss (for binary classification)
optimizer = optim.Adam(model.parameters(), lr=0.01)

# Split the features and categorical columns
X_team = X_train[:, 3:4]  # Categorical feature (team)

# Training loop
epochs = 1000
for epoch in range(epochs):
    optimizer.zero_grad()
    outputs = model(X_train[:, :3], X_team)  # Pass numerical + categorical features
    loss = criterion(outputs, y_train)
    loss.backward()
    optimizer.step()
    
    if epoch % 200 == 0:
        print(f'Epoch [{epoch}/{epochs}], Loss: {loss.item():.4f}')

# Testing the model on a new game prediction
new_game = torch.tensor([[0.70, 112, 104, 1]], dtype=torch.float32)  # A game with the Warriors
new_game_team = new_game[:, 3:4]  # Extract the team column for embedding

# Get probability prediction
win_probability = model(new_game[:, :3], new_game_team).item() * 100
print(f'Predicted Probability of Winning: {win_probability:.2f}%')

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Sample dataset (Each row: [Win %, PPG, Def Rating, Home/Away, Team Name], Label: [Win/Loss])
data = np.array([
    [0.75, 110, 105, 1, 0, 1],  # Lakers at Home
    [0.60, 108, 107, 0, 1, 0],  # Warriors Away
    [0.55, 105, 110, 1, 2, 0],  # Celtics at Home
    [0.80, 115, 102, 0, 0, 1],  # Lakers Away
    [0.40, 100, 112, 1, 1, 0],  # Warriors at Home
    [0.45, 102, 111, 0, 2, 1]   # Celtics Away
], dtype=np.float32)

# Split into features (X) and labels (y)
X = data[:, :-1]  # All columns except the last (features)
y = data[:, -1:]  # Last column (target win/loss)

# Normalize numerical features (Win %, PPG, Def Rating) (first 3 columns)
scaler = MinMaxScaler()
X[:, :3] = scaler.fit_transform(X[:, :3])  # Normalize only first 3 columns

# Convert to PyTorch tensors
X_train = torch.tensor(X, dtype=torch.float32)
y_train = torch.tensor(y, dtype=torch.float32)

# Model parameters
num_numerical = 3  # Win %, PPG, Def Rating
num_teams = 3  # Unique teams (Lakers, Warriors, Celtics)
embedding_dim = 2  # Small embedding for team name

# Define the Neural Network
class BasketballNN(nn.Module):
    def __init__(self):
        super(BasketballNN, self).__init__()
        self.team_embedding = nn.Embedding(num_embeddings=num_teams, embedding_dim=embedding_dim)
        
        # Fully connected layers
        self.fc1 = nn.Linear(num_numerical + embedding_dim + 1, 16)  # Numerical + Team Embedding + Home/Away
        self.fc2 = nn.Linear(16, 8)
        self.fc3 = nn.Linear(8, 1)
        self.sigmoid = nn.Sigmoid()  # Probability output

    def forward(self, x_numerical, x_home_away, x_team):
        team_embedded = self.team_embedding(x_team.long())  # Convert team index to embeddings
        x = torch.cat([x_numerical, x_home_away, team_embedded], dim=1)  # Concatenate all inputs
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        x = self.sigmoid(x)  # Output probability
        return x

# Initialize the model
model = BasketballNN()
criterion = nn.BCELoss()  # Binary Cross Entropy Loss (for probabilities)
optimizer = optim.Adam(model.parameters(), lr=0.01)

# Convert categorical columns to tensor
X_home_away = X_train[:, 3:4]  # Home/Away (kept as float)
X_team = X_train[:, 4:5]  # Team Name

# Training loop
epochs = 1000
for epoch in range(epochs):
    optimizer.zero_grad()
    outputs = model(X_train[:, :3], X_home_away, X_team)  # Pass numerical + categorical features
    loss = criterion(outputs, y_train)
    loss.backward()
    optimizer.step()
    
    if epoch % 200 == 0:
        print(f'Epoch [{epoch}/{epochs}], Loss: {loss.item():.4f}')

# Testing the model on a new game prediction
new_game = np.array([[0.70, 112, 104, 1, 1]], dtype=np.float32)  # A team playing at home
new_game[:, :3] = scaler.transform(new_game[:, :3])  # Normalize numerical features
new_game_tensor = torch.tensor(new_game, dtype=torch.float32)

# Split into parts
new_game_numerical = new_game_tensor[:, :3]
new_game_home_away = new_game_tensor[:, 3:4]
new_game_team = new_game_tensor[:, 4:5]

# Get probability prediction
win_probability = model(new_game_numerical, new_game_home_away, new_game_team).item() * 100
print(f'Predicted Probability of Winning: {win_probability:.2f}%')
